# %% [markdown]
# ####NAME : JAHNAVI NUTHALAPATI
# uta id :1001827251

# %% [markdown]
# ######REFERECES
# https://medium.com/@randerson112358/python-logistic-regression-program-5e1b32f964db
# https://stackoverflow.com/questions/54317168/plotting-a-dataframe-with-seaborn-pairplot-in-multiple-colors
# Others have been mentioned in the report.

# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd

# Print the IRIS DATA
pd.read_csv("iris.csv")
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# %matplotlib inline
import numpy as np 
from sklearn import datasets 
import seaborn.apionly as sns  
import matplotlib.pyplot as plt

# %%
df_data = sns.load_dataset('iris') #Defining the graph coordinates for case:1

# %%
#I have implemented the covariance operation. It will receive two arrays as parameters and will return the covariance(x,y) value. This might help in differentiating dependancies.
def covariance (u, v): 
    uhat=np.mean(u) 
    vhat=np.mean(v) 
    epsiQ=0
    for x,y in zip (u,v):
        epsiQ=epsiQ+(x-uhat)*(y-vhat) 
    return epsiQ/(len(u)-1)

# %%
#Comparision of implemented function of the NumPy function
print (covariance ([3,5,7], [2,6,9]))

print (np.cov([3,5,7], [2,6,9]))

#I have taken the above values as test cases as one of the parameters is petal and sepal(2* criteria so raised the power by 2), other is the 3 types of iris (used the 3 multiples to test)
# Out:
# 7.0
# [[ 4.          7.        ]
#  [ 7.         12.33333333]]

# %%
def correlation (g, h):

    return(covariance(g,h)/(np.std(g,    ddof=1)*np.std(h,   ddof=1))) #ddof=1 is unbiased std

# %%
# Implementation and comparsion of Correlation of the NumPy function
print (correlation([2,4,3,1], [5,7,9,8]))
print (correlation([2,4,3,1], [5,7,9,8]))

# Another test case values
print (correlation ([8,6,7,5], [4,3,2,1]))

print (np.corrcoef ([8,6,7,5], [4,3,2,1]))
# Out:
# 0.07559289460184544
# 0.07559289460184544
# 0.8
# [[1.  0.8]
#  [0.8 1. ]]

# %%
iris_3 = sns.load_dataset("iris")
sns.pairplot(iris_3, hue ='species')

# %%
X=df_data['petal_width'] 
Y=df_data['petal_length']

# %%
import seaborn as sns 
  
df_data = sns.load_dataset('iris') 
  
# style used as a theme of graph  
# for example if we want black  
# graph with grid then write "blackgrid" 
sns.set_style("whitegrid") 
  
# sepal_length, petal_length are iris 
# feature data height used to define 
# Height of graph whereas hue store the 
# class of iris dataset. 
sns.FacetGrid(iris, hue ="species",  
              height = 5).map(plt.scatter,  
                              'sepal_length',  
                              'petal_length').add_legend()

# %%
plt.scatter(X,Y)

# %%
def predict(a, b, f): return b * f + a

# %%
def error(a, b, f, g): #L1 return y_i - predict(a, b, i_i)

    def sum_sq_e(a, b, i, j): #L2

        return sum(error(a, b, f, g) ** 2 for f, g in zip(i, j))

# %%
def correlation_fit(i, j):

    b = correlation(i, j) * np.std(j, ddof=1) / np.std(i,ddof=1) 
    a = np.mean(j) - b * np.mean(i)

    return a, b

# %%
a, b = correlation_fit(X, Y)
print(a)

print(b)
# Out:
# 1.0835580328505143
# 2.229940495121862

# %%
X=df_data['petal_width'] 
Y=df_data['petal_length']

# %%
plt.scatter(X,Y) 
xr=np.arange(0,3.75) 
plt.plot(xr,(xr*b)+a)
